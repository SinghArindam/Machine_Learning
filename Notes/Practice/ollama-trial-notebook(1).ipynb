# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !curl -fsSL https://ollama.com/install.sh | sh
import subprocess
process = subprocess.Popen("ollama serve", shell=True) #runs on a different thread
# Out:
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ############################################################################################# 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %% [markdown]
# # Download model

# %%
# !ollama pull llama3
# !ollama pull llama3.2
# !ollama pull deepseek-r1:32b
# !ollama pull deepseek-r1:14b
# !ollama pull deepseek-r1:8b
# !ollama pull deepseek-r1:7b
# !ollama pull deepseek-r1:1.5b
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest
# pulling 6a0746a1ec1a...   0% ▕                ▏    0 B/4.7 GB                  pulling manifest
# pulling 6a0746a1ec1a...   0% ▕                ▏    0 B/4.7 GB                  pulling manifest
# pulling 6a0746a1ec1a...   0% ▕                ▏    0 B/4.7 GB                  pulling manifest
# pulling 6a0746a1ec1a...   0% ▕                ▏ 2.7 MB/4.7 GB                  pulling manifest
# pulling 6a0746a1ec1a...   0% ▕                ▏  21 MB/4.7 GB                  pulling manifest
# pulling 6a0746a1ec1a...   1% ▕                ▏  38 MB/4.7 GB                  pulling manifest
# pulling 6a0746a1ec1a...   1% ▕                ▏  50 MB/4.7 GB                  pulling manifest
# pulling 6a0746a1ec1a...   2% ▕                ▏  80 MB/4.7 GB                  pulling manifest
# ...

# %% [markdown]
# # Function for Ollama

# %%
# !pip -q install ollama

# %%
import ollama

def answer_ai(msg,model='deepseek-r1:1.5b'):
    response = ollama.chat(model=model, messages=[
      {
        'role': 'user',
        'content': msg,
      },
    ])
    return response['message']['content']

# %%
model = 'deepseek-r1:32b'

# %%
msg = "why is the sky blue"

print(answer_ai(msg,model))
# Out:
# <think>
# Okay, so I'm trying to figure out why the sky appears blue. I've heard that it's something to do with the way light scatters in the atmosphere, but I'm not entirely sure how that works. Let me break this down step by step.
#
# First, sunlight is white, right? But when we look up at the sky, especially on a clear day, it looks blue. So somewhere along the way, the white light must be changing color. I remember learning about something called Rayleigh scattering in school, but I don't recall all the details. Maybe that's related.
#
# Sunlight is made up of different colors, each with their own wavelengths. The colors we see are red, orange, yellow, green, blue, indigo, and violet. Red has a longer wavelength, while violet has a shorter one. So maybe the scattering depends on the wavelength of the light?
#
# ...

# %%
# !ollama list
# Out:
# NAME                ID              SIZE      MODIFIED
# deepseek-r1:1.5b    a42b25d8c10a    1.1 GB    8 minutes ago
# deepseek-r1:7b      0a8c26691023    4.7 GB    8 minutes ago
# deepseek-r1:8b      28f8fd6cdc67    4.9 GB    9 minutes ago
# deepseek-r1:14b     ea35dfe18182    9.0 GB    9 minutes ago
# deepseek-r1:32b     38056bbcbb2d    19 GB     10 minutes ago
# llama3.2:latest     a80c4f17acd5    2.0 GB    13 minutes ago
# llama3:latest       365c0bd3c000    4.7 GB    13 minutes ago

# %%
msg = "give me code to create a portfolio website in flutter using python flet"

print(answer_ai(msg,model))
# Out:
# <think>
# Okay, so the user wants to create a portfolio website using Flutter with Python Flet. I need to provide them with a clear and concise code example that they can follow.
#
# First, I should outline what a portfolio website typically includes. Usually, it has sections like About Me, Skills, Projects, and Contact. So, I'll structure the app with these sections.
#
# I remember that in Flet, we use Column and Row layouts to organize content. For responsiveness, using ResponsiveView with breakpoints makes sense so the layout adjusts on different screen sizes.
#
# Starting with the header section: it should have the name and a navigation menu. Using a Row for side-by-side placement and adding icons from material_design_icons will make it look professional. I'll include links for each section to allow navigation.
#
# ...

# %%
msg = "good, now give me code to make it beautiful and responsive with animations as well"

print(answer_ai(msg,model))
# Out:
# <think>
# Alright, the user wants to make their website both beautiful and responsive with animations. I need to provide a comprehensive solution that covers these aspects.
#
# First, I'll start by setting up the basic HTML structure. I know that using semantic tags like <header>, <nav>, and <section> will help with responsiveness and SEO. Including a container class will allow me to center content and manage layouts easily.
#
# Next, for styling, I'll use CSS variables to define a consistent color scheme. This makes it easier to maintain and change colors later. I'll choose a primary color for the background, a secondary for buttons and interactive elements, and an accent for highlights or animations.
#
# To ensure responsiveness, I'll use Flexbox for layout management. Flexbox is great because it allows items to adjust based on screen size. For example, the navigation links can be in a row on larger screens and stack vertically on smaller devices using flex-direction: column.
#
# ...
